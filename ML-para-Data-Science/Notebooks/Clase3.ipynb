# %% [markdown]
# # Introducción a Matplotlib para DS 🖼️

# %% [markdown]
# Activar el modo *inline* - las figuras aparecerán automáticamente incrustadas en el notebook.

# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from IPython.display import HTML
HTML('<iframe src="http://matplotlib.org/gallery.html" width="800" height="600"></iframe>') #anchura y altura
# Out:
# C:\Users\Daniel\Anaconda3\lib\site-packages\IPython\core\display.py:689: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe src="http://matplotlib.org/gallery.html" width="800" height="600"></iframe>

# %% [markdown]
# # Interfaz pyplot

# %%
# ?plt.plot

# %%
plt.plot([0, 0.1, 0.2, 0.5,0.6], [1, -1, 0, 3, -1], 'rs')# - 'go' - 'go-' - 'rs'

# %% [markdown]
# La tarea más habitual a la hora de trabajar con matplotlib es representar una función. Lo que tendremos que hacer es definir un dominio y evaluarla en dicho dominio. Por ejemplo:

# %% [markdown]
# $$f(x) = e^{-x^2}$$

# %%
# definición de función
def f(x):
    return np.exp(-x ** 2)

# %% [markdown]
# Definimos el dominio con la función `np.linspace`, que crea un vector de puntos equiespaciados:

# %%
x = np.linspace(-1, 5, num=30)

# %%
x
# Out:
# array([-1.        , -0.79310345, -0.5862069 , -0.37931034, -0.17241379,
#         0.03448276,  0.24137931,  0.44827586,  0.65517241,  0.86206897,
#         1.06896552,  1.27586207,  1.48275862,  1.68965517,  1.89655172,
#         2.10344828,  2.31034483,  2.51724138,  2.72413793,  2.93103448,
#         3.13793103,  3.34482759,  3.55172414,  3.75862069,  3.96551724,
#         4.17241379,  4.37931034,  4.5862069 ,  4.79310345,  5.        ])

# %%
plt.plot(x, f(x))

# %%
# etiquetas, label="Función f(x)")
plt.plot(x, f(x))
plt.xlabel("Eje $x$")
plt.ylabel("$f(x)$")
# Out:
# Text(0, 0.5, '$f(x)$')

# %%
plt.plot(x, f(x))
plt.xlabel("Eje $x$")
plt.ylabel("$f(x)$")
plt.legend("f(x)")
plt.title("Función $f(x)$")
# Out:
# Text(0.5, 1.0, 'Función $f(x)$')

# %% [raw]
# Notamos varias cosas:
#
# Con diversas llamadas a funciones dentro de `plt.` se actualiza el gráfico *actual*. Esa es la forma de trabajar con la interfaz pyplot.

# %% [markdown]
# ### Personalización

# %%
plt.plot(x, f(x), 'ro')

# %%
plt.plot(x, 1 - f(x), 'g--')

# %%
plt.plot(x, f(x), 'ro')
plt.plot(x, 1 - f(x), 'g--')

# %%
plt.plot(x, f(x), 'ro')
plt.plot(x, 1 - f(x), 'g--')
plt.grid(True)

# %%
plt.plot(x, f(x), color='red', linestyle='', marker='o')
plt.plot(x, 1 - f(x), c='y', ls='--')
plt.grid(True)

# %% [markdown]
# La lista de posibles argumentos y abreviaturas está disponible en la documentación de la función `plot` http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.plot.

# %%
 print(plt.style.available)
# Out:
# ['bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark-palette', 'seaborn-dark', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'seaborn', 'Solarize_Light2', 'tableau-colorblind10', '_classic_test']

# %%
plt.style.use('ggplot')

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.show()

# %%
plt.style.use('ggplot')
plt.plot([-1, 2, -3, 4], [1, 4, -9, 16])
plt.show()

# %%
plt.style.use('ggplot')
plt.plot(np.sort([-1, 2, -3, 4]), np.sort([1, 4, -9, 16]))
plt.show()

# %%
plt.style.use('dark_background')
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.show()

# %%
plt.style.use('fivethirtyeight')
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.show()

# %%
plt.style.use('fivethirtyeight')
plt.plot(x, f(x))
plt.plot(x, 1 - f(x))

# %%
plt.style.use('dark_background')
plt.plot(x, f(x))
plt.plot(x, 1 - f(x))

# %% [markdown]
# ### Scaterplots o de dispersión de puntos

# %%
N = 100
x = np.random.randn(N)
y = np.random.randn(N)
x,y
# Out:
# (array([-0.83157896,  0.73491658,  0.2191936 , -0.22445317, -0.32422106,
#         -0.44324629,  1.45378285,  0.51358601,  0.95041703, -2.1846146 ,
#          0.22912342,  1.04216856, -0.95317139,  0.28489805,  0.68249671,
#         -0.27474845,  0.29764048,  1.19661183, -0.51109542, -1.83347369,
#          2.47516387,  1.91581984,  0.69890241, -0.95917008, -0.58461788,
#         -0.79591229, -0.8741784 , -2.84003182, -0.37454417, -1.56758903,
#          0.20341821,  1.08796189, -0.12708969,  2.42976981, -2.53191801,
#          0.6174709 ,  1.02537773,  1.15766473,  0.05050698,  0.10325047,
#          0.00614389,  1.18756987, -0.34895302,  0.93785568,  0.10969848,
#         -0.74317953, -0.08810444, -0.12630391, -0.2623056 , -0.69884388,
#         -0.74982445, -0.30687036,  1.91990638, -0.20273341,  0.89964106,
#          0.6779223 , -0.62937225, -0.33139568, -1.25067461, -0.45392136,
#         -0.08368716,  0.57033986,  0.97741088,  0.28953703, -0.66614223,
# ...

# %%
plt.style.use('ggplot')
plt.scatter(x, y)

# %%
s =50*np.random.randn(N)
c = 50*np.random.randn(N)
s,c
# Out:
# (array([ -34.20591723,  -64.252672  ,   46.96768569,   88.99031535,
#          -12.68945189,  -44.64943936,  -47.18962108,   36.28199982,
#           -6.52176697,   78.09119563,  -30.16742373, -106.94412473,
#          -29.51742031,   -3.60387927,   21.97278369,  -17.70646396,
#           -0.75336228,    0.29178618,   49.05974804,  -58.65747625,
#           49.219034  ,    1.47932986,  -24.23975346,  -12.26509184,
#           27.36329316,  -83.84895782,   -8.01766338,   22.13659266,
#           78.07994395,   40.21254121,  -37.6977804 ,    7.55255789,
#         -103.03686737,  -79.56903775,   27.31298437,   89.85965688,
#          -95.56087781,   77.77692899,   11.3873062 ,    1.87269532,
#          -12.69111719,  -11.28005247,  -51.6866062 ,  -13.45812979,
#            4.29395813,  147.58716047,  -68.09724931,  -77.05411086,
#           79.55150765,   12.14908282,  -20.74499915,   69.43380786,
#           -6.62840652,   -5.38507603,  -68.52901225,    0.98862196,
# ...

# %%
plt.scatter(x, y, s, c, cmap=plt.cm.Oranges)
# Out:
# C:\Users\Daniel\Anaconda3\lib\site-packages\matplotlib\collections.py:874: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
plt.scatter(x, y, s=s, c=c, cmap=plt.cm.Blues)
plt.colorbar()

# %% [markdown]
# ### Box plots

# %% [markdown]
# Creamos variables aleatorias

# %%
## Creating some data
np.random.seed(10)
data_1 = np.random.normal(100, 10, 200)
data_1
# Out:
# array([113.31586504, 107.15278974,  84.54599708,  99.9161615 ,
#        106.21335974,  92.79914439, 102.65511586, 101.08548526,
#        100.04291431,  98.25399789, 104.3302619 , 112.03037374,
#         90.34934329, 110.28274078, 102.2863013 , 104.45137613,
#         88.63397788, 101.35136878, 114.84537002,  89.20195114,
#         80.22271719,  82.56627704, 102.66070164, 123.84967331,
#        111.23691253, 116.72622213, 100.99149216, 113.97996377,
#         97.28752012, 106.13204185,  97.32682811,  94.50690986,
#        101.32708296,  95.23857985, 113.08473081, 101.95013279,
#        104.00209988,  96.62367663, 112.56472264,  92.68030498,
#        106.60231551,  96.49128109,  90.6056664 ,  95.10662783,
#         91.95408858,  97.87302361,  96.60859754, 103.12169936,
#        105.6515267 ,  98.52579742,  99.74094663, 102.89094204,
#         94.60120929, 107.0816002 , 108.42224738, 102.03580797,
#        123.94703665, 109.17458938,  98.87727529,  96.37819553,
# ...

# %%
"""
=================================
Box plots with custom fill colors
=================================

This plot illustrates how to create two types of box plots
(rectangular and notched), and how to fill them with custom
colors by accessing the properties of the artists of the
box plots. Additionally, the ``labels`` parameter is used to
provide x-tick labels for each sample.

A good general reference on boxplots and their history can be found
here: http://vita.had.co.nz/papers/boxplots.pdf

"""
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# Random test data
np.random.seed(123)
all_data = [np.random.normal(0, std, 100) for std in range(1, 4)]
all_data

np.shape(all_data)

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 9)) #Figsize, width=12 pulgadas, heigth=9 pulgadas

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 9)) #Figsize, width=12, heigth=9
# boxplot rectangular
bplot1 = axes[0].boxplot(all_data,
                         vert=True,   
                         patch_artist=True)   

bplot2 = axes[1].boxplot(all_data,
                         notch=True,  
                         vert=True,   
                         patch_artist=True)   

# los colores de la paleta
colors = ['pink', 'lightblue', 'lightgreen']
for bplot in (bplot1, bplot2):
    for patch, color in zip(bplot['boxes'], colors):
        patch.set_facecolor(color)

# adicionando nombres a las abscisas
plt.setp(axes, xticks=[y+1 for y in range(len(all_data))],
         xticklabels=['x1', 'x2', 'x3', 'x4'])

plt.show()data_2 = np.random.normal(80, 30, 200)
data_2
# Out:
# array([ 83.99412491, 116.08231622,  49.25741099,  84.81197489,
#         46.08574139,  21.76100957, 109.59793451,  80.84682102,
#         55.32897207,  32.40344717,  67.95581542, 120.26537853,
#         92.0740728 ,  68.81715751,  59.83929691,  83.17436248,
#         33.58083827, 120.34419532,  95.09567545, 115.83051807,
#         63.09482986, 105.64486269, 100.63714177,  34.00793845,
#         84.46882103,  89.45333505,  62.75247008,  69.19486597,
#         93.0855589 ,  78.86246354,  49.85850942,  97.7435926 ,
#         86.83452092,  87.47535974,  82.8728971 ,  93.47065192,
#         71.41993977,  54.11725102,  57.74525484, 113.16725408,
#         19.46844042,  96.21622139,  36.73103352,  31.73448911,
#         49.80294315,  72.27399126, 101.91522341,  29.04795527,
#        130.22226637, 114.91171101,  76.02279222,  71.29262574,
#         51.39402747,  97.64121781,  82.06404412, 122.36192913,
#         59.41353155,  96.43831781,  78.90852387,  54.58951241,
# ...

# %%
data_3 = np.random.normal(90, 20, 200)
data_3
# Out:
# array([ 99.24771101,  65.60288932,  93.85145678,  98.70900777,
#         57.30111728,  98.69874549, 117.95638772,  92.4933355 ,
#         72.17097196,  78.46213317,  88.50102264,  79.56447104,
#         25.91197311, 119.25421985,  80.66194757,  86.41960598,
#        108.49495269,  94.7048953 ,  80.22783489,  88.14036917,
#        100.70802764, 101.01689402,  86.16955893, 105.89395255,
#        105.70192998,  80.24551166,  69.8827027 ,  96.55150731,
#        101.580969  ,  80.80148904,  81.28368172, 100.72537103,
#         93.14029967, 117.17578278, 100.3069049 , 137.68249246,
#        100.58380536,  72.07712327,  86.04379765,  88.09048336,
#         56.39108162, 103.53416391,  91.21455647,  89.53917623,
#         78.93363145,  67.87753527,  85.65730211,  72.49155246,
#         90.21562858,  71.87506359,  61.68493579,  91.89416623,
#         93.87601221, 100.86470171,  91.12671559, 119.3131001 ,
#         77.28061577, 112.19010457,  70.14735032,  76.35317053,
# ...

# %%
## Combining the different data in a list
data_to_plot = [data_1, data_2, data_3]
data_to_plot
# Out:
# [array([113.31586504, 107.15278974,  84.54599708,  99.9161615 ,
#         106.21335974,  92.79914439, 102.65511586, 101.08548526,
#         100.04291431,  98.25399789, 104.3302619 , 112.03037374,
#          90.34934329, 110.28274078, 102.2863013 , 104.45137613,
#          88.63397788, 101.35136878, 114.84537002,  89.20195114,
#          80.22271719,  82.56627704, 102.66070164, 123.84967331,
#         111.23691253, 116.72622213, 100.99149216, 113.97996377,
#          97.28752012, 106.13204185,  97.32682811,  94.50690986,
#         101.32708296,  95.23857985, 113.08473081, 101.95013279,
#         104.00209988,  96.62367663, 112.56472264,  92.68030498,
#         106.60231551,  96.49128109,  90.6056664 ,  95.10662783,
#          91.95408858,  97.87302361,  96.60859754, 103.12169936,
#         105.6515267 ,  98.52579742,  99.74094663, 102.89094204,
#          94.60120929, 107.0816002 , 108.42224738, 102.03580797,
#         123.94703665, 109.17458938,  98.87727529,  96.37819553,
# ...

# %%
np.shape(data_to_plot)
# Out:
# (3, 200)

# %%
np.size(data_to_plot)
# Out:
# 600

# %%
# Create the boxplot
bp = plt.boxplot(data_to_plot)

# %%
"""
=================================
Box plots with custom fill colors
=================================

This plot illustrates how to create two types of box plots
(rectangular and notched), and how to fill them with custom
colors by accessing the properties of the artists of the
box plots. Additionally, the ``labels`` parameter is used to
provide x-tick labels for each sample.

A good general reference on boxplots and their history can be found
here: http://vita.had.co.nz/papers/boxplots.pdf

"""
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# Random test data
np.random.seed(123)
all_data = [np.random.normal(0, std, 100) for std in range(1, 4)]
all_data
# Out:
# [array([-1.0856306 ,  0.99734545,  0.2829785 , -1.50629471, -0.57860025,
#          1.65143654, -2.42667924, -0.42891263,  1.26593626, -0.8667404 ,
#         -0.67888615, -0.09470897,  1.49138963, -0.638902  , -0.44398196,
#         -0.43435128,  2.20593008,  2.18678609,  1.0040539 ,  0.3861864 ,
#          0.73736858,  1.49073203, -0.93583387,  1.17582904, -1.25388067,
#         -0.6377515 ,  0.9071052 , -1.4286807 , -0.14006872, -0.8617549 ,
#         -0.25561937, -2.79858911, -1.7715331 , -0.69987723,  0.92746243,
#         -0.17363568,  0.00284592,  0.68822271, -0.87953634,  0.28362732,
#         -0.80536652, -1.72766949, -0.39089979,  0.57380586,  0.33858905,
#         -0.01183049,  2.39236527,  0.41291216,  0.97873601,  2.23814334,
#         -1.29408532, -1.03878821,  1.74371223, -0.79806274,  0.02968323,
#          1.06931597,  0.89070639,  1.75488618,  1.49564414,  1.06939267,
#         -0.77270871,  0.79486267,  0.31427199, -1.32626546,  1.41729905,
# ...

# %%
np.shape(all_data)
# Out:
# (3, 100)

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 9)) #Figsize, width=12 pulgadas, heigth=9 pulgadas

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 9)) #Figsize, width=12, heigth=9
# boxplot rectangular
bplot1 = axes[0].boxplot(all_data,
                         vert=True,   
                         patch_artist=True)   

bplot2 = axes[1].boxplot(all_data,
                         notch=True,  
                         vert=True,   
                         patch_artist=True)   

# los colores de la paleta
colors = ['pink', 'lightblue', 'lightgreen']
for bplot in (bplot1, bplot2):
    for patch, color in zip(bplot['boxes'], colors):
        patch.set_facecolor(color)

# adicionando nombres a las abscisas
plt.setp(axes, xticks=[y+1 for y in range(len(all_data))],
         xticklabels=['x1', 'x2', 'x3', 'x4'])

plt.show()

# %% [markdown]
# ### Scatter Matrix

# %%
data=np.random.randn(1000, 4)
data.shape
# Out:
# (1000, 4)

# %%
import pandas as pd
df = pd.DataFrame(np.random.randn(1000, 4), columns=['a', 'b', 'c', 'd'])
df
# Out:
#             a         b         c         d
# 0   -0.274829 -0.617008  0.784477  0.079590
# 1    0.305133 -0.562393 -0.600167  0.440759
# 2   -1.063866 -0.495916 -0.553204 -1.119496
# 3   -0.327035  1.047376 -0.224598 -1.163616
# 4    0.557779  2.288356  0.578038 -0.965811
# 5   -0.982372  0.897965  1.098385 -0.278272
# 6    0.500119  0.457936  1.362017  0.995505
# 7   -0.955135  0.829731 -1.394844  0.794987
# 8   -1.072624 -0.495188  0.991432 -1.138277
# 9   -0.524018  0.243916  0.996002 -0.326339
# 10  -0.673822  0.490987  0.556657 -1.406780
# 11   1.432884 -0.518688 -0.361816 -0.614507
# 12  -0.076439  0.914152 -0.857362  0.085452
# 13   0.493330  0.719846  0.660624 -0.965911
# 14  -0.364916 -0.424707 -2.108956 -2.002135
# 15  -1.095597  0.935843  0.067567 -0.322935
# 16  -0.087804 -0.908564 -1.340046  0.219302
# 17  -0.360373  1.693296  0.285951  0.230449
# 18   1.420471  1.405633  0.232195  0.254670
# 19   0.577782 -1.103696 -0.566152 -0.699466
# ...

# %%
import pandas as pd
df = pd.DataFrame(np.random.randn(1000, 4), columns=['a', 'b', 'c', 'd'])

spm = pd.tools.plotting.scatter_matrix(df, alpha=0.2, figsize=(6, 6), diagonal='hist')
# Out:
# C:\Users\Daniel\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.
#   after removing the cwd from sys.path.

# %%
spm = pd.tools.plotting.scatter_matrix(df, alpha=0.2, figsize=(6, 6), diagonal='kde') #kernel desnsity estimation
# Out:
# C:\Users\Daniel\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.
#   """Entry point for launching an IPython kernel.

# %%
import pandas as pd
# ?pd.read_csv

# %%
import pandas as pd
datos = pd.read_csv('C:/Users/Daniel/Documents/Solo_OnLine/Graficos Python/Datos_Graficos.csv' , sep=';')

# %%
datos.head()
# Out:
#       ID Estado_Civil     Genero  Ingreso  Hijos       Educacion  \
# 0  11000       Casado  Masculino      900      2       Bachiller
# 1  11047       Casado   Femenino      300      3         Maestro
# 2  11061       Casado  Masculino      800      2  Uni_Imcompleta
# 3  11090      Soltero  Masculino      900      2  Uni_Imcompleta
# 4  11116       Casado  Masculino      700      5  Uni_Imcompleta
#
#       Ocupacion Propietario_Casa  Autos Distancia_Viajes    Region  Edad  \
# 0   Profesional               Si      0        1-2 Miles  Pacifico    40
# 1  Especialista               No      2        1-2 Miles  Pacifico    56
# 2  Especialista               Si      2       5-10 Miles  Pacifico    52
# 3   Profesional               Si      1        2-5 Miles       USA    48
# 4  Especialista               Si      2       5-10 Miles  Pacifico    43
#
#   Compra_Bicicleta
# 0               Si
# 1               Si
# 2               Si
# 3               Si
# 4               No

# %%
datos.sort_values(['Ocupacion','Hijos'], ascending = False)
# Out:
#         ID Estado_Civil     Genero  Ingreso  Hijos       Educacion  \
# 22   11287       Casado  Masculino      700      5  Uni_Imcompleta
# 30   11415      Soltero  Masculino      900      5  Uni_Imcompleta
# 31   11434       Casado  Masculino     1700      5  Uni_Imcompleta
# 58   11890       Casado   Femenino      700      5        Graduado
# 82   12291      Soltero  Masculino      900      5  Uni_Imcompleta
# 102  12664       Casado   Femenino     1300      5  Uni_Imcompleta
# 128  13133      Soltero  Masculino     1000      5       Bachiller
# 144  13382       Casado  Masculino      700      5  Uni_Imcompleta
# 149  13466       Casado  Masculino      800      5  Uni_Imcompleta
# 184  14177       Casado  Masculino      800      5  Uni_Imcompleta
# 264  15559       Casado  Masculino      600      5       Bachiller
# 287  15982       Casado  Masculino     1100      5  Uni_Imcompleta
# 295  16145      Soltero   Femenino      700      5        Graduado
# ...

# %% [markdown]
# # Visualización con seaborn

# %%
import seaborn as sns
from seaborn import lmplot

# estilo
sns.set(style = "white")

# cargar datos
datos = pd.read_excel('C:/Users/Daniel/Documents/Solo_OnLine/Graficos Python/bodyfat.xlsx', sheet_name = 'bodyfat')

# Gráfico de dispersion
lmplot('grasa_corporal', 'peso', data = datos, fit_reg = False) # False

# %%
lmplot('grasa_corporal', 'peso', data = datos, ci = None)

# %%
datos.head()
# Out:
#    densidad  grasa_corporal  edad    peso  estatura  cuello  pecho  abdomen  \
# 0    1.0708            12.3    23  154.25     67.75    36.2   93.1     85.2
# 1    1.0853             6.1    22  173.25     72.25    38.5   93.6     83.0
# 2    1.0414            25.3    22  154.00     66.25    34.0   95.8     87.9
# 3    1.0751            10.4    26  184.75     72.25    37.4  101.8     86.4
# 4    1.0340            28.7    24  184.25     71.25    34.4   97.3    100.0
#
#    cadera  muslo  rodilla  tobillo  biceps  antebrazo  muneca sexo
# 0    94.5   59.0     37.3     21.9    32.0       27.4    17.1  Fem
# 1    98.7   58.7     37.3     23.4    30.5       28.9    18.2  Fem
# 2    99.2   59.6     38.9     24.0    28.8       25.2    16.6  Mas
# 3   101.2   60.1     37.3     22.8    32.4       29.4    18.2  Fem
# 4   101.9   63.2     42.2     24.0    32.2       27.7    17.7  Fem

# %%
lmplot('grasa_corporal', 'peso', hue = "sexo", data = datos)

# %%
from seaborn import kdeplot
kdeplot(datos.grasa_corporal)

# %%
kdeplot(datos.peso, datos.grasa_corporal)

# %%
from seaborn import distplot
distplot(datos.grasa_corporal, kde = False) # False

# %%
distplot(datos.grasa_corporal, hist = False)

# %%
distplot(datos.grasa_corporal, vertical=True)

# %%
from seaborn import boxplot
boxplot(datos.grasa_corporal, orient = "v") # "v"

# %%
boxplot(x = "sexo", y = "grasa_corporal", data = datos)

# %%
boxplot(x = "sexo", y = "grasa_corporal", hue="sexo", data = datos)

# %%
from seaborn import violinplot
violinplot(x = "sexo", y = "grasa_corporal", hue="sexo", data = datos)

# %%
datos.head()
# Out:
#    densidad  grasa_corporal  edad    peso  estatura  cuello  pecho  abdomen  \
# 0    1.0708            12.3    23  154.25     67.75    36.2   93.1     85.2
# 1    1.0853             6.1    22  173.25     72.25    38.5   93.6     83.0
# 2    1.0414            25.3    22  154.00     66.25    34.0   95.8     87.9
# 3    1.0751            10.4    26  184.75     72.25    37.4  101.8     86.4
# 4    1.0340            28.7    24  184.25     71.25    34.4   97.3    100.0
#
#    cadera  muslo  rodilla  tobillo  biceps  antebrazo  muneca sexo
# 0    94.5   59.0     37.3     21.9    32.0       27.4    17.1  Fem
# 1    98.7   58.7     37.3     23.4    30.5       28.9    18.2  Fem
# 2    99.2   59.6     38.9     24.0    28.8       25.2    16.6  Mas
# 3   101.2   60.1     37.3     22.8    32.4       29.4    18.2  Fem
# 4   101.9   63.2     42.2     24.0    32.2       27.7    17.7  Fem

# %%
sns.pairplot(datos, hue = "sexo", diag_kind = "hist")

# %%
sns.set(style = "darkgrid")
datos_sns = pd.read_csv('Datos_Graficos.csv', sep=';')
g = sns.FacetGrid(datos_sns, row = "Ocupacion", col="Genero", margin_titles = True)
bins = np.linspace(0, 1000, 10)
g.map(plt.hist, "Ingreso", color = "steelblue", bins = bins, lw = 0)

# %%
datos_sns.head()
# Out:
#       ID Estado_Civil     Genero  Ingreso  Hijos       Educacion  \
# 0  11000       Casado  Masculino      900      2       Bachiller
# 1  11047       Casado   Femenino      300      3         Maestro
# 2  11061       Casado  Masculino      800      2  Uni_Imcompleta
# 3  11090      Soltero  Masculino      900      2  Uni_Imcompleta
# 4  11116       Casado  Masculino      700      5  Uni_Imcompleta
#
#       Ocupacion Propietario_Casa  Autos Distancia_Viajes    Region  Edad  \
# 0   Profesional               Si      0        1-2 Miles  Pacifico    40
# 1  Especialista               No      2        1-2 Miles  Pacifico    56
# 2  Especialista               Si      2       5-10 Miles  Pacifico    52
# 3   Profesional               Si      1        2-5 Miles       USA    48
# 4  Especialista               Si      2       5-10 Miles  Pacifico    43
#
#   Compra_Bicicleta
# 0               Si
# 1               Si
# 2               Si
# 3               Si
# 4               No

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# estilo
sns.set(style = "white", palette = "muted", color_codes = True)

# divición del panel gráfico
f, axes = plt.subplots(2, 2, figsize=(7, 7), sharex=True)
#sns.despine(left = True)

# datos a graficar
d = datos_sns.Ingreso

# histograma
sns.distplot(d, kde = False, color = "b", ax = axes[0, 0])

# densidad con rug
sns.distplot(d, hist = False, rug = True, color = "r", ax = axes[0, 1])

# area de densidad
sns.distplot(d, hist = False, color = "g", kde_kws = {"shade": True}, ax = axes[1, 0])

# histograma con densidad
sns.distplot(d, color = "m", ax = axes[1, 1])

plt.setp(axes, yticks=[])
plt.tight_layout()

# %%
import numpy as np
import seaborn as sns

# estilo
sns.set(style = "ticks")

x = datos_sns.Ingreso
y = datos_sns.Hijos

sns.jointplot(x, y, kind = "hex", color = "#4CB391")

# %%
import seaborn as sns

# Estilo
sns.set(style = "white")

# Plot miles per gallon against horsepower with other semantics
sns.relplot(x = "Ingreso", y = "Edad", hue = "Region", size = "Hijos",
            sizes = (40, 400), alpha = 0.5, palette = "muted",
            height = 6, data = datos_sns)

# %%
import seaborn as sns

# estilo
sns.set(style="darkgrid")

g = sns.jointplot("Ingreso", "Edad", data = datos_sns, kind = "reg",
                  color="m", height=7)

# %% [markdown]
# # Visualización con plotly

# %% [markdown]
# ## ¿Qué es plotly?

# %% [markdown]
# La biblioteca de gráficos Python de Plotly crea gráficos en línea interactivos con calidad de publicación

# %%
import plotly
plotly.__version__
# Out:
# '3.10.0'

# %%
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

plot([go.Scatter(x=[1, 2, 3], y=[3, 1, 6])])
# Out:
# 'temp-plot.html'

# %%
import pandas as pd
# cargar datos
datos = pd.read_excel('bodyfat.xlsx', sheet_name = 'bodyfat')

# %%
import plotly.offline
import plotly.graph_objs as go

plotly.offline.plot({"data": [go.Scatter(x = datos.peso, y = datos.grasa_corporal)],
                     "layout": go.Layout(title = "grafico_1")},
                     image = 'jpeg', image_filename = 'test')
# Out:
# 'temp-plot.html'

# %%
init_notebook_mode(connected=True)
import plotly.graph_objs as go

iplot([{"x": [1, 2, 3], "y": [3, 1, 6]}])
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="e235ffae-f82e-4761-a20a-a13ce932e621" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
# ...

# %%
import cufflinks as cf
iplot(cf.datagen.lines().iplot(asFigure=True,
                               kind='scatter',xTitle='Dates',yTitle='Returns',title='Returns'))
# Out:
# <div>
#
#
#             <div id="117fb595-5c1d-4432-a321-3048a35a12ea" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("117fb595-5c1d-4432-a321-3048a35a12ea")) {
#                     Plotly.newPlot(
#                         '117fb595-5c1d-4432-a321-3048a35a12ea',
# ...

# %%
import plotly.plotly as py 

fig = py.get_figure('https://plot.ly/~jackp/8715', raw=True)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="6006e123-6997-41df-bbf1-a3d5262df5e2" class="plotly-graph-div" style="height:900px; width:1000px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("6006e123-6997-41df-bbf1-a3d5262df5e2")) {
#                     Plotly.newPlot(
#                         '6006e123-6997-41df-bbf1-a3d5262df5e2',
# ...

# %%
init_notebook_mode(connected=True)
import plotly.plotly as py
import plotly.graph_objs as go

data = [
    go.Box(
        y=datos.estatura,
        boxpoints='all',
        jitter=0.3,
        pointpos=-1.8
    )
]
iplot(data)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="4efef0f7-afac-410a-a5cc-7fa94f9b67be" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
# ...

# %%
import plotly.plotly as py
import plotly.graph_objs as go

import numpy as np

x0 = datos.estatura
x1 = datos.cadera

t = go.Box(x=x0)
y = go.Box(x=x1)
data = [t, y]
iplot(data)
# Out:
# <div>
#
#
#             <div id="8fa162b1-8d15-49f1-986a-7a300d2134a3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("8fa162b1-8d15-49f1-986a-7a300d2134a3")) {
#                     Plotly.newPlot(
#                         '8fa162b1-8d15-49f1-986a-7a300d2134a3',
# ...

# %%
import plotly.plotly as py
import plotly.graph_objs as go

import numpy as np

y0 = datos.estatura
y1 = datos.cadera

trace0 = go.Box(
    y=y0
)
trace1 = go.Box(
    y=y1
)
data = [trace0, trace1]
iplot(data)
# Out:
# <div>
#
#
#             <div id="82fe6354-cfc8-4c11-a8e7-5006c9a5a5fd" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("82fe6354-cfc8-4c11-a8e7-5006c9a5a5fd")) {
#                     Plotly.newPlot(
#                         '82fe6354-cfc8-4c11-a8e7-5006c9a5a5fd',
# ...

# %%
import plotly.plotly as py
import plotly.graph_objs as go
import numpy as np

y0 = datos.estatura
y1 = datos.cadera

trace0 = go.Box(
    y=y0,
    name = 'Estatura',
    marker = dict(
        color = 'rgb(214, 12, 140)',
    )
)
trace1 = go.Box(
    y=y1,
    name = 'Cadera',
    marker = dict(
        color = 'rgb(0, 128, 128)',
    )
)
data = [trace0, trace1]
iplot(data)
# Out:
# <div>
#
#
#             <div id="3db48216-0d67-4df8-9131-295d87dac574" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("3db48216-0d67-4df8-9131-295d87dac574")) {
#                     Plotly.newPlot(
#                         '3db48216-0d67-4df8-9131-295d87dac574',
# ...

# %%
import plotly.plotly as py
import plotly.figure_factory as ff
import numpy as np
 
x1 = datos.estatura[datos.sexo=='Fem']
x2 = datos.estatura[datos.sexo=='Mas']

hist_data = [x1, x2]

group_labels = ['Fem', 'Mas']

fig = ff.create_distplot(hist_data, group_labels, bin_size = .2)

iplot(fig, filename='Distplot with Multiple Datasets')
# Out:
# <div>
#
#
#             <div id="a7364739-a962-4a1f-9dd1-670650138f6d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("a7364739-a962-4a1f-9dd1-670650138f6d")) {
#                     Plotly.newPlot(
#                         'a7364739-a962-4a1f-9dd1-670650138f6d',
# ...

# %%
import plotly.plotly as py
import plotly.figure_factory as ff
import numpy as np

x1 = datos.estatura[datos.sexo=='Fem']
x2 = datos.estatura[datos.sexo=='Mas']

hist_data = [x1, x2]

group_labels = ['Fem', 'Mas']
colors = ['#333F44', '#37AA9C']

fig = ff.create_distplot(hist_data, group_labels, show_hist = False, colors = colors)

fig['layout'].update(title='Curvas y rug')

iplot(fig, filename='Curvas y rug')
# Out:
# <div>
#
#
#             <div id="b61cbaaf-fecf-4130-9a13-d26a5a426f7c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("b61cbaaf-fecf-4130-9a13-d26a5a426f7c")) {
#                     Plotly.newPlot(
#                         'b61cbaaf-fecf-4130-9a13-d26a5a426f7c',
# ...
